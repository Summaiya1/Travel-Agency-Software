# %%
def temp():
    p.destroy()
    

def check( package_name,temp1,temp2):
    q.destroy() 
    import tkinter as t5
    import csv
    r = t5.Tk()
    temp3 = float(temp1) + float(temp2)
    
    with open("international packages.csv",'r') as f:
        x = csv.reader(f)
        for i in x:
            if(i[1]== package_name):
                airline=i[9]
                Duration = i[6]
                Hotel =i[5]
                
    label1 = Label(r,text = "Receipt"  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label1.grid( row = 1, column = 3 , padx = 10,pady = 10)
    label2 = Label(r,text = "Package Name"  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label3 = Label(r,text = package_name  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label4 = Label(r,text = "Amount"  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label5 = Label(r,text = "$"+"{0:.2f}".format(temp3), bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label6 = Label(r,text = "Hotel"  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold" ))                                                                                                       
    label7 = Label(r,text = Hotel  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label8 = Label(r,text = "Airline"  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label9 = Label(r,text = airline  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label10 = Label(r,text = "Duration"  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label11 = Label(r,text = Duration , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    
    
    label2.grid( row = 2, column = 2 , padx = 10,pady = 10)
    label3.grid( row = 2, column = 4 , padx = 10,pady = 10)
    label4.grid( row = 3, column = 2 , padx = 10,pady = 10)
    label5.grid( row = 3, column = 4 , padx = 10,pady = 10)
    label6.grid( row = 4, column = 2 , padx = 10,pady = 10)
    label7.grid( row = 4, column = 4 , padx = 10,pady = 10)
    label8.grid( row = 5, column = 2 , padx = 10,pady = 10)
    label9.grid( row = 5, column = 4 , padx = 10,pady = 10)
    label10.grid( row = 6, column = 2 , padx = 10,pady = 10)
    label11.grid( row = 6, column = 4 , padx = 10,pady = 10)
    
    def close():
        r.destroy()
        
    button1 = Button(r,text="OK",width = 20,background = "RoyalBlue4",foreground = "gold", font = ("helvetica", 14, "bold"),command = close)
    button1.grid(row = 7, column = 3)
    
    r.mainloop()
def child4(price_value , package_name):
    global temp,q
    temp =  price_value
    p.destroy()
    import tkinter as t4
    import PIL 
    from PIL import ImageTk, Image
    from tkinter import ttk
    q = t4.Tk()
    q.configure(bg = 'black')
    back_image = ImageTk.PhotoImage(PIL.Image.open('summaiya/IMG-9420 (2).jpg'))
    label_ = t4.Label(image = back_image)
    var = IntVar()
    
    labelframe = LabelFrame(q, text="Transportation",width = 30,foreground = "gold", background = "VioletRed4", font = ("helvetica", 18, "bold")) 
    labelframe.grid(row = 6, column = 2,padx = 20 , pady = 20)
    
    label_a = Label(q,text = "Package Name"  , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label_b = Label(q,text = package_name   , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label_c = Label(q,text = "Standard Price"   , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label_d = Label(q,text = '$' + temp , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label_e = Label(q,text = "Final Price"   , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label_f = Label(q,text = '$' + temp , bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label_g = Label(q,text = "Additional Charges", bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label_h = Label(q,text = '$0', bg = "RoyalBlue4",width = 20,height = 2,foreground = 'gold',font = ("helvetica",14, "bold"))
    label_f.grid(row = 4, column = 4,padx = 5 ,pady = 5)
    label_g.grid(row = 5, column = 2,padx = 5,pady = 5)
    label_h.grid(row = 5, column = 4,padx = 5 ,pady = 5)
    
    def change_price():
            global temp1
            temp1 = float(temp) + float(var.get())
            label_f.config(text = "$"+ "{0:.2f}".format(temp1) )
            
    R1 = Radiobutton(labelframe, text="Business",width = 10, variable=var,background = "RoyalBlue4",foreground = "gold",indicatoron = 0, font = ("helvetica", 18, "bold"), value=100,command = change_price)
    R1.pack( anchor = W )
    R2 = Radiobutton(labelframe, text="Economy", width = 10,variable=var,background = "RoyalBlue4", foreground = "gold",indicatoron = 0, font = ("helvetica", 18, "bold"), value=80,command = change_price)
    R2.pack(anchor = NW)
    R3 = Radiobutton(labelframe, text="Lower AC",width = 10, variable=var,background = "RoyalBlue4",  
                foreground = "gold",indicatoron = 0, font = ("helvetica", 18, "bold"), value=60,command = change_price)
    R3.pack( anchor = NW)

    label_.grid(row = 1, column = 3,padx = 5 ,pady = 5)
    label_a.grid(row = 2, column = 2,padx = 5 ,pady = 5) 
    label_b.grid(row = 2, column = 4,padx = 5,pady = 5) 
    label_c.grid(row = 3, column = 2,padx = 5 ,pady = 5)
    label_d.grid(row = 3, column = 4,padx = 5 ,pady = 5)
    label_e.grid(row = 4, column = 2,padx = 5 ,pady = 5)
    
    if(var.get() == 100):
        R1.invoke()
    elif(var.get() == 80):
        R2.invoke()
    elif(var.get() == 60):
        R3.invoke()
    
    
    var1 = IntVar()
    var2 = IntVar()
    var3 = IntVar()
    def change_price1():
        global temp2
        if(var1.get() == 1 and var2.get() == 0 and var3.get() == 0):
            temp2 = 30 
            label_h.config(text = "$" + str(temp2)) 
        if(var1.get() == 1 and var2.get() == 1 and var3.get() == 0):
            temp2 = 30 + 60
            label_h.config(text = '$' + str(temp2)) 
        if(var1.get() == 1 and var2.get() == 1 and var3.get() == 1):
            temp2 = 30 + 60 +80
            label_h.config(text = '$' + str(temp2)) 
        if(var1.get() == 0 and var2.get() == 1 and var3.get() == 1):
            temp2 =  60 + 80
            label_h.config(text = '$' + str(temp2)) 
        if(var1.get() == 1 and var2.get() == 0 and var3.get() == 1):
            temp2 =  30 + 80
            label_h.config(text = '$' + str(temp2)) 
        if(var1.get() == 0 and var2.get() == 0 and var3.get() == 1):
            temp2 =  80
            label_h.config(text = '$' + str(temp2)) 
        if(var1.get() == 0 and var2.get() == 1 and var3.get() == 0):
            temp2 =  60
            label_h.config(text = '$' + str(temp2)) 
        if(var1.get() == 0 and var2.get() == 0 and var3.get() == 0):
            temp2 = 0 
            label_h.config(text = '$' + str(temp2)) 
        
    
    labelframe1 = LabelFrame(q, text="Meal",foreground = "gold",width = 30, background = "VioletRed4", font = ("helvetica", 18, "bold")) 
    labelframe1.grid(row = 6, column = 3)  
    C1 = Checkbutton(labelframe1, text="Breakfast",width = 10, variable=var1,background = "RoyalBlue4",command = change_price1,foreground = "black", font = ("helvetica", 18, "bold"))
    C1.pack( anchor = W )
    C2 = Checkbutton(labelframe1, text="Lunch", width = 10,variable=var2,background = "RoyalBlue4", command =change_price1,foreground = "black", font = ("helvetica", 18, "bold"))
    C2.pack(anchor = NW)
    C3 = Checkbutton(labelframe1, text="Dinner",width = 10, variable=var3,background = "RoyalBlue4",command = change_price1,  
                foreground = "black", font = ("helvetica", 18, "bold"))
    C3.pack( anchor = NW)
    
    labelframe2 = LabelFrame(q, text="Persons",foreground = "gold",width = 20, background = "VioletRed4", font = ("helvetica", 18, "bold")) 
    labelframe2.grid(row = 6, column = 4)  
    C4 = Checkbutton(labelframe2, text="Children",width = 10,background = "RoyalBlue4",foreground = "black", font = ("helvetica", 18, "bold"))
    C4.pack( anchor = W )
    C5 = Checkbutton(labelframe2, text="Infant", width = 10,background = "RoyalBlue4",foreground = "black", font = ("helvetica", 18, "bold"))
    C5.pack(anchor = NW)
    C6 = Checkbutton(labelframe2, text="Adult", width = 10,background = "RoyalBlue4",foreground = "black", font = ("helvetica", 18, "bold"))
    C6.pack(anchor = NW)
    
    C1.invoke()
    C2.invoke()
    C3.invoke()
    get_month = StringVar()
    get_date = StringVar()
   
    label_A = Label(q,text="Select Your Date Of Departure",width = 25,height = 2,background = "RoyalBlue4",foreground = "black", font = ("helvetica", 12,"bold"))
    label_A.grid(row = 7, column = 2 )
    combo1 = ttk.Combobox(q,textvariable =get_month , values=["January", "February","March","April","May","June","July","August","September","October","November","December"])
    combo1.grid(row = 7 , column = 3)
    
    date = []
    for i in range(1,32):
        date.append(i)
        
    combo2 = ttk.Combobox(q,textvariable =get_date, values=date)
    combo2.grid(row = 7 , column = 4)
    
    button1 = Button(q,text="Register",width = 20,background = "RoyalBlue4",foreground = "gold", font = ("helvetica", 18, "bold"),command = lambda :check(package_name,temp1,temp2))
    button1.grid(row = 8 , column = 3 , padx = 10,pady = 10)
   
    print(get_month.get())
    print( get_date.get())
    
    q.mainloop()
    
def show_details(a):
    o.destroy()
    global temp0
    temp0 = temp0 + 1
    global p , x , y
    import csv
    import tkinter as t3
    from PIL import ImageTk, Image
    p = t3.Tk()
    p.configure(bg = 'thistle2')
    p.attributes('-fullscreen', True)
    
    def show_picture(x,y):
        from PIL import ImageTk, Image
        
        image_1 = Image.open(x)
        image_1 = image_1.resize((280, 180), Image.ANTIALIAS)
        back_image = ImageTk.PhotoImage(image_1) 
        
        image1 = Image.open(y)
        image1 = image1.resize((280, 180), Image.ANTIALIAS)
        back_image1 = ImageTk.PhotoImage(image1)
        
        label_1 = t3.Label(p,image = back_image)
        label_1.photo = back_image # to make image not being garbage collected.
        label_2= t3.Label(p,image = back_image1)
        label_2.photo = back_image1 
        
        label_1.grid(row = 1,column = 1)
        label_2.grid(row = 1,column = 3)
        
    
    with open("international packages.csv",'r') as f:
        x = csv.reader(f)
        for i in x:
            if(i[0]== a):
                label_1a = Label(p,text = i[1] , bg = "Black",fg = "white",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))
                name = i[1]
                label_2a = Label(p,text = '$'+i[2] , bg = "Black",fg = "white",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))  
                price = i[2]
                label_3 = Label(p,text = i[3] , bg = "Black",fg = "white",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))  
                label_4 = Label(p,text = i[4] , bg = "Black",fg = "white",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))
                label_5 = Label(p,text = i[5] , bg = "Black",fg = "white",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))  
                label_6 = Label(p,text = i[6] , bg = "Black",fg = "white",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))  
                label_7 = Label(p,text = i[7] , bg = "Black",fg = "white",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold")) 
                label_8 = Label(p,text = i[8] , bg = "Black",fg = "white",width = 60,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))  
                label_9 = Label(p,text = i[9] , bg = "Black",fg = "white",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))       
            if(a == '1') :
                show_picture('summaiya/dubai1.jpg','summaiya/dubaii.jpg')
            elif(a=='2'):
                show_picture('summaiya/thailanddd.jpg','summaiya/thailandd.jpg')
            elif (a == '3'):
                show_picture('summaiya/singapore2.jpg','summaiya/singapore3.jpg')
            elif (a == '4'):
                show_picture('summaiya/mauritius2.jpg','summaiya/mauritius1.jpg')
            elif (a == '5'):
                show_picture('summaiya/egypt2.jpg','summaiya/egypt3.jpg')
            elif (a == '6'):
                show_picture('summaiya/malaysia3.jpg','summaiya/malaysia4.jpg')
            elif (a == '7'):
                show_picture('summaiya/switzerland2.jpg','summaiya/switzerland3.jpg')
            elif (a == '8'):
                show_picture('summaiya/istanbul1.jpg','summaiya/istanbul3.jpg')
            elif (a == '9'):
                show_picture('summaiya/bangkok2.jpg','summaiya/bangkok3.jpg')
            elif (a == '10'):
                show_picture('summaiya/paris2.jpg','summaiya/paris3.jpg')
            elif (a == '11'):
                show_picture('summaiya/srilanka2.jpg','summaiya/srilanka3.jpg')
                
                 
    label_a = Label(p,text = "Package Name"  , bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))
    label_b = Label(p,text =  "Package Price", bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))
    label_c = Label(p,text = "Source" , bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))
    label_d = Label(p,text = "Destination" , bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))
    label_e = Label(p,text = "Hotel" , bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))
    label_f = Label(p,text = "Days" , bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold")) 
    label_g = Label(p,text = "Persons" , bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold"))
    label_h = Label(p,text = "Visits" , bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold")) 
    label_i = Label(p,text = "Flight" , bg = "Black",width = 20,height = 1,foreground = 'gold',font = ("helvetica",12, "bold")) 
    button_1 = Button(text = "Click Here To See Another Package",  bg = "white",foreground = 'black',width = 40,height = 2,command = child2,cursor='hand2',font = ("helvetica",14, "bold"))
    button_2 = Button(text = "Register",  bg = "white",foreground = 'black',width = 20,height = 2,command = lambda:child4(price,name),cursor='hand2',font = ("helvetica",14, "bold"))

    label_a.grid(row = 2,column = 1,padx = 10 ,pady =10)
    label_b.grid(row =3 ,column = 1,padx = 10 ,pady =10)
    label_c.grid(row =4 ,column =1,padx = 10 ,pady =10)
    label_d.grid(row =5 ,column =1 ,padx = 10 ,pady =10)
    label_e.grid(row =6 ,column =1 ,padx = 10 ,pady =10)
    label_f.grid(row =7 ,column =1 ,padx = 10 ,pady =10)
    label_g.grid(row = 8,column =1,padx = 10 ,pady =10)
    label_h.grid(row =9 ,column = 1,padx = 10 ,pady =10)
    label_i.grid(row = 10,column = 1,padx = 10 ,pady =10)
    
    button_1.grid(row = 12,column = 3)
    button_2.grid(row = 12,column = 2)
    
    label_1a.grid(row = 2,column = 3,padx = 10 ,pady =10)
    label_2a.grid(row = 3,column = 3,padx = 10 ,pady =10)
    label_3.grid(row =4 ,column = 3,padx = 10 ,pady =10)
    label_4.grid(row =5 ,column = 3,padx = 10 ,pady =10)
    label_5.grid(row =6 ,column = 3,padx = 10 ,pady =10)
    label_6.grid(row =7 ,column = 3,padx = 10 ,pady =10)
    label_7.grid(row =8 ,column = 3,padx = 10 ,pady =10)
    label_8.grid(row =9 ,column =3 ,padx = 10 ,pady =10)
    label_9.grid(row = 10,column =3 ,padx = 10 ,pady =10)
    
    p.mainloop()
    
    
def child2():
    
    if(int(temp0)>0):
        temp()
        
    import tkinter as t2
    import PIL 
    from PIL import ImageTk, Image
    global o
    o = t2.Tk()
    o.attributes('-fullscreen', True)
    Scrollable_body = Scrollable(o,32)
    back_image0 = ImageTk.PhotoImage(PIL.Image.open('summaiya/IMG-9420 (2).jpg'))
    label_ = t2.Label( Scrollable_body,image = back_image0,bg = 'black')
    back_image1 = ImageTk.PhotoImage(PIL.Image.open('summaiya/1.PNG'))
    back_image2 = ImageTk.PhotoImage(PIL.Image.open('summaiya/mauritius3.jpg'))
    back_image3 = ImageTk.PhotoImage(PIL.Image.open('summaiya/istanbul2.jpg'))
    image = Image.open('summaiya/bangkok1.jpg')
    image = image.resize((280, 180), Image.ANTIALIAS)
    back_image4 = ImageTk.PhotoImage(image)
    image1 = Image.open('summaiya/egypt1.jpg')
    image1 = image1.resize((280, 180), Image.ANTIALIAS)
    back_image5 = ImageTk.PhotoImage(image1)
    image2 = Image.open('summaiya/malaysia2.jpg')
    image2 = image2.resize((280, 180), Image.ANTIALIAS)
    back_image6 = ImageTk.PhotoImage(image2)
    image3 = Image.open('summaiya/paris1.jpg')
    image3 = image3.resize((280, 180), Image.ANTIALIAS)
    back_image7 = ImageTk.PhotoImage(image3)
    image4 = Image.open('summaiya/singapore1.jpg')
    image4 = image4.resize((280, 180), Image.ANTIALIAS)
    back_image8 = ImageTk.PhotoImage(image4)
    image5 = Image.open('summaiya/switzerland1.jpg')
    image5 = image5.resize((280, 180), Image.ANTIALIAS)
    back_image9 = ImageTk.PhotoImage(image5)
    image6 = Image.open('summaiya/Thailand.jpg')
    image6 = image6.resize((280, 180), Image.ANTIALIAS)
    back_image10 = ImageTk.PhotoImage(image6)
    image7 = Image.open('summaiya/srilanka1.jpg.')
    image7 = image7.resize((280, 180), Image.ANTIALIAS)
    back_image11 = ImageTk.PhotoImage(image7)
    
 
    label_1 = t2.Label(Scrollable_body,image = back_image1)
    label_2= t2.Label(Scrollable_body,image = back_image2)
    label_3= t2.Label(Scrollable_body,image = back_image3)
    label_5= t2.Label(Scrollable_body,image = back_image4)
    label_6= t2.Label(Scrollable_body,image = back_image5)
    label_7= t2.Label(Scrollable_body,image = back_image6)
    label_8= t2.Label(Scrollable_body,image = back_image7)
    label_9= t2.Label(Scrollable_body,image = back_image8)
    label_10= t2.Label(Scrollable_body,image = back_image9)
    label_11= t2.Label(Scrollable_body,image = back_image10)
    label_12= t2.Label(Scrollable_body,image = back_image11)
    
    font_1 = font.Font(family = 'helvetica',size = 12,weight = "bold")
    font_2 = font.Font(family = "Lucida Calligraphy",size = 12,weight = "bold")
    label_4 = t2.Label(Scrollable_body,text = "Click  the  package  name  to  see  Package  details",bg = "red",fg = "white",width = 45,height = 2)
    label_4['font']= font_1
    button1 = t2.Button(Scrollable_body,text = "Majestic Dubai",bg="black",fg='white', width = 20,height = 2,cursor='hand2',command = lambda:show_details('1'))
    button1['font'] = font_2
    button2 = t2.Button(Scrollable_body,text = "Enchanting  Mauritius",bg="black",fg='white', width = 20,height = 2,cursor='hand2',command = lambda:show_details('4'))
    button2['font'] = font_2
    button3 = t2.Button(Scrollable_body,text = "Istanbul Tour",bg="black",fg='white', width = 20,height = 2,cursor='hand2',command = lambda:show_details('8'))
    button3['font'] = font_2
    button4 = t2.Button(Scrollable_body,text = "Dazzle in Bangkok",bg="black",fg='white', width = 20,height = 2,cursor='hand2',font = ("Lucida Calligraphy",12, "bold"),command = lambda:show_details('9'))
    button5 = t2.Button(Scrollable_body,text = "Exotic Malaysia Tour",bg="black",fg='white', width = 20,height = 2,cursor='hand2',font = ("Lucida Calligraphy",12, "bold"),command = lambda:show_details('6'))
    button6 = t2.Button(Scrollable_body,text = "Magical Switzerland",bg="black",fg='white', width = 20,height = 2,cursor='hand2',font = ("Lucida Calligraphy",12, "bold"),command = lambda:show_details('7'))
    button7 = t2.Button(Scrollable_body,text = "Paris with Disneyland",bg="black",fg='white', width = 20,height = 2,cursor='hand2',font = ("Lucida Calligraphy",12, "bold"),command = lambda:show_details('10'))
    button8 = t2.Button(Scrollable_body,text = "Super Singapore Trip",bg="black",fg='white', width = 20,height = 2,cursor='hand2',font = ("Lucida Calligraphy",12, "bold"),command = lambda:show_details('3'))
    button9 = t2.Button(Scrollable_body,text = "Egypt Holidays",bg="black",fg='white', width = 20,height = 2,cursor='hand2',font = ("Lucida Calligraphy",12, "bold"),command = lambda:show_details('5'))
    button10 = t2.Button(Scrollable_body,text = "Grand Tour Of Srilanka",bg="black",fg='white', width = 20,height = 2,cursor='hand2',font = ("Lucida Calligraphy",12, "bold"),command = lambda:show_details('11'))
    button11 = t2.Button(Scrollable_body,text = "Fun in Thailand",bg="black",fg='white', width = 20,height = 2,cursor='hand2',font = ("Lucida Calligraphy",12, "bold"),command = lambda:show_details('2'))
    
    label_.grid(row = 0 , column =4, columnspan = 6,padx = 10 ,pady =10)
    label_4.grid(row = 1,column = 4,columnspan = 6,padx = 10 ,pady =10)
    label_1.grid(row = 2,column = 1,columnspan = 2,padx = 20 ,pady =20)
    label_2.grid(row = 2,column = 5,columnspan = 2,padx = 20 ,pady =20)
    label_3.grid(row = 2,column = 9,columnspan = 2,padx = 20 ,pady =20)
    label_5.grid(row = 2,column = 12,columnspan = 2,padx = 10 ,pady =10)
    label_6.grid(row = 4,column = 1,columnspan = 2,padx = 20 ,pady =20)
    label_7.grid(row = 4,column = 5,columnspan = 2,padx = 20 ,pady =20)
    label_8.grid(row = 4,column = 9,columnspan = 2,padx = 20 ,pady =20)
    label_9.grid(row = 4,column = 12,columnspan = 2,padx = 10 ,pady =10)
    label_10.grid(row = 6,column = 1,columnspan = 2,padx = 20 ,pady =20)
    label_11.grid(row = 6,column = 5,columnspan = 2,padx = 20 ,pady =20)
    label_12.grid(row = 6,column = 9,columnspan = 2,padx = 20 ,pady =20)
    
    button1.grid(row = 3,column = 1,columnspan = 2,padx = 10 ,pady =10)
    button2.grid(row = 3,column = 5,columnspan = 2,padx = 10 ,pady =10)
    button3.grid(row = 3,column = 9,columnspan = 2,padx = 10 ,pady =10)
    button4.grid(row = 3,column = 12,columnspan = 2,padx = 10 ,pady =10)
    button5.grid(row = 5,column = 5,columnspan = 2,padx = 10 ,pady =10)
    button6.grid(row = 7,column = 1,columnspan = 2,padx = 10 ,pady =10)
    button7.grid(row = 5,column = 9,columnspan = 2,padx = 10 ,pady =10)
    button8.grid(row = 5,column = 12,columnspan = 2,padx = 10 ,pady =10)
    button9.grid(row = 5,column = 1,columnspan = 2,padx = 10 ,pady =10)
    button10.grid(row = 7,column = 9,columnspan = 2,padx = 10 ,pady =10)
    button11.grid(row = 7,column = 5,columnspan = 2,padx = 10 ,pady =10)
    Scrollable_body.update()
    o.mainloop()
    

def insert():
    from tkinter import messagebox
    a = entry4.get()
    b = entry5.get()
    c = entry3.get()
    if( a== b and a != "" and b!= "" and c != ""):
        insert_into_file(c,a)
    else :
        messagebox.showinfo("message",'Sorry the password entries are not matching or invalid username') 
        
def insert_into_file(a,b):
    import csv
    with open('passwords.csv','a', newline = '') as f:  # create the file and also write
        data_handler1 = csv.writer(f,delimiter = ',') 
        data_handler1.writerow([a,b])
        messagebox.showinfo("message",'You are now signed up')
        n.destroy()
        child2()
        
    
def child1():
    m.destroy()
    import PIL 
    from PIL import ImageTk, Image
    import tkinter as t1
    global n
    n = t1.Tk() 
    back_image = ImageTk.PhotoImage(PIL.Image.open('summaiya/IMG-9420 (2).jpg'))
    label_ = t1.Label(image = back_image)
    font_1 = font.Font(family = 'helvetica',size = 12,weight = "bold")
    label_1 = Label(n,text='FIRST NAME',bg = "RoyalBlue4",fg = "white",width = 20,height = 2)
    label_1['font']= font_1
    label_2 = Label(n,text='LAST NAME',bg = "RoyalBlue4",fg = "white",width = 20,height = 2)
    label_2['font']= font_1    
    label_3 = Label(n,text='USERNAME ',bg = "RoyalBlue4",fg = "white",width = 20,height = 2)
    label_3['font']= font_1
    label_4 = Label(n,text='PASSWORD ',bg = "RoyalBlue4",fg = "white",width = 20,height = 2)
    label_4['font']= font_1
    label_5 = Label(n,text=' CONFIRM PASSWORD ',bg = "RoyalBlue4",fg = "white",width = 20,height = 2)
    label_5['font']= font_1
    button1 = t1.Button(n,text = "Sign Up",bg="black",fg='white', width = 20,height = 2,cursor='hand2',command = insert)
    button1['font'] = font_1
    global entry1 , entry2 , entry3 , entry4 , entry5
    entry1 = Entry(n)
    entry2 = Entry(n)
    entry3 = Entry(n)
    entry4 = Entry(n)
    entry5 = Entry(n)
    label_.grid(row = 0,column = 1,columnspan = 4,padx = 15 , pady =15 )
    label_1.grid(row = 2,column = 1,padx = 15 , pady =15)
    label_2.grid(row = 4,column = 1)
    label_3.grid(row = 6,column = 1,padx = 15,pady =15)
    label_4.grid(row = 8,column = 1)
    label_5.grid(row = 10,column = 1,padx = 15,pady =15)
    entry1.grid(row = 2 , column = 2)
    entry2.grid(row = 4 , column = 2)
    entry3.grid(row = 6, column = 2)
    entry4.grid(row = 8 , column = 2)
    entry5.grid(row = 10 , column = 2)
    button1.grid(row = 12 , column = 2,columnspan = 3,padx = 10 , pady =10)
   # m.destroy() # closes the m screen
    n.mainloop()

def take_text():
    global entry_1
    global entry_2
    username = entry_1.get()
    password = entry_2.get()
    check_password(username,password)
    
def check_password(u,p):
    with open("passwords.csv",'r') as f:
        x = csv.reader(f)
        temp = 1
        try :
            for i in x:
                 for j in range(0,1):
                        if(i[j]== u and i[j+1] == p ):
                            m.destroy()
                            child2()
                            temp = 0
                            break     
        except:
            msg = messagebox.showinfo("message",'Sorry incorrect Username or password')
        if(temp != 0) :
             msg = messagebox.showinfo("message",'Sorry incorrect Username or password')

import PIL                
import tkinter as t
from tkinter import font
from PIL import ImageTk, Image
from tkinter import messagebox
import csv 
from tkinter import * 
global m
m = t.Tk() # m is master  
global temp0 , w
w = 0
a = 0
if (a==0):
    temp0 = 0
topframe = Frame(m)
topframe.configure(bg = "black")
topframe.pack()
bottomframe = Frame(m)
bottomframe.pack(side = BOTTOM)
back_image = ImageTk.PhotoImage(PIL.Image.open('summaiya/IMG-9420 (1).jpg'))
label_ = t.Label(image = back_image)
font_1 = font.Font(family = 'helvetica',size = 12,weight = "bold")
label_1 = Label(bottomframe,text='USERNAME',bg = "RoyalBlue4",fg = "white",width = 20,height = 2)
label_1['font']= font_1
label_2 = Label(bottomframe,text="PASSWORD",bg = "RoyalBlue4",fg = "white",width = 20,height = 2)
label_2['font'] = font_1
button_2 = Button(bottomframe,text = " CLICK HERE TO SIGN UP :)", bg = 'white', fg = 'red' , width = 25, height = 1,cursor = 'hand2',command = child1)
font_2 = font.Font(family = "helvetica",size = 14,weight = "bold")
font_2.configure(underline = True)
button_2['font'] = font_2
button1 = t.Button(bottomframe,text = "Sign in",bg="black",fg='white', width = 25,height = 2,command = take_text,cursor='hand2')
button1['font'] = font_1
entry_1 = Entry(bottomframe)
entry_2 = Entry(bottomframe)
label_1.grid(row = 0,padx = 10 ,pady =10)
label_2.grid(row = 1)
entry_1.grid(row=0,column = 1)
entry_2.grid(row=1,column = 1)
button1.grid(row=2,column = 0,columnspan = 3,padx = 15 , pady =15)
button_2.grid(row=3,column = 0,columnspan = 4, padx = 20 , pady =20)
label_.pack()
m.mainloop()

# %%
#Scrollbar Class for Scrollable Body

# %%
import tkinter as tk
from tkinter import ttk

class Scrollable(tk.Frame):
    """
       Make a frame scrollable with scrollbar on the right.
       After adding or removing widgets to the scrollable frame, 
       call the update() method to refresh the scrollable area.
    """
    
    def __init__(self, frame, width=16):
        frame.configure(bg = "black")
        scrollbar = tk.Scrollbar(frame, width=width)
        scrollbar.pack(side=tk.RIGHT, fill=tk.Y, expand=False)

        self.canvas = tk.Canvas(frame, yscrollcommand=scrollbar.set)
        self.canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

        scrollbar.config(command=self.canvas.yview)
        self.canvas.bind('<Configure>', self.__fill_canvas)

        # base class initialization
        tk.Frame.__init__(self, frame)         

        # assign this obj (the inner frame) to the windows item of the canvas
        self.windows_item = self.canvas.create_window(0,0, window=self, anchor=tk.NW)


    def __fill_canvas(self, event):
        "Enlarge the windows item to the canvas width"

        canvas_width = event.width
        self.canvas.itemconfig(self.windows_item, width = canvas_width)        

    def update(self):
        "Update the canvas and the scrollregion"

        self.update_idletasks()
        self.canvas.config(scrollregion=self.canvas.bbox(self.windows_item))
